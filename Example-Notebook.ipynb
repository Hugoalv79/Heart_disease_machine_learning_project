# %% [markdown]
# # Hello World

# %%
print("Hello World, I´m learning about Jupyter Notebooks")
# Out:
# Hello World, I´m learning about Jupyter Notebooks

# %%
a = 5

# %%
a = 6

# %%
a
# Out:
# 6

# %%
1+1
# Out:
# 2
